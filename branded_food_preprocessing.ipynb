# %%
import pandas as pd
from generatePDF import df2pdf

# %%
branded_folder = "FoodData_Central_branded_food_csv_2023-10-26"

branded_df = pd.read_csv(f'data_source/{branded_folder}/branded_food.csv')
branded_food_df = pd.read_csv(f'data_source/{branded_folder}/food.csv')
branded_food_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/food_nutrient.csv')
branded_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/nutrient.csv')
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_15552\201363813.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_food_df = pd.read_csv(f'data_source/{branded_folder}/food.csv')
# C:\Users\Michael\AppData\Local\Temp\ipykernel_15552\201363813.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_food_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/food_nutrient.csv')

# %%
branded_df
# Out:
#           fdc_id                               brand_owner     brand_name  \
# 0        1105904  Richardson Oilseed Products (US) Limited            NaN
# 1        1105905                     CAMPBELL SOUP COMPANY            NaN
# 2        1105906                     CAMPBELL SOUP COMPANY            NaN
# 3        1105907                     CAMPBELL SOUP COMPANY            NaN
# 4        1105908                     CAMPBELL SOUP COMPANY            NaN
# ...          ...                                       ...            ...
# 1947150  2662264                             Target Stores  MARKET PANTRY
# 1947151  2662265                             Target Stores  MARKET PANTRY
# 1947152  2662266                             Target Stores  MARKET PANTRY
# 1947153  2662267                             Target Stores  MARKET PANTRY
# 1947154  2662268                       General Mills, Inc.           EPIC
#
#         subbrand_name      gtin_upc  \
# 0                 NaN   27000612323
# ...

# %%
branded_food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1947155 entries, 0 to 1947154
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   fdc_id            int64
#  1   data_type         object
#  2   description       object
#  3   food_category_id  float64
#  4   publication_date  object
#  5   market_country    object
#  6   trade_channel     object
#  7   microbe_data      object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 118.8+ MB

# %%
branded_food_nutrient_df
# Out:
#                 id   fdc_id  nutrient_id   amount  data_points  derivation_id  \
# 0         13706927  1105904         1257     0.00          NaN           71.0
# 1         13706930  1105904         1293    53.33          NaN           71.0
# 2         13706926  1105904         1253     0.00          NaN           75.0
# 3         13706921  1105904         1092     0.00          NaN           75.0
# 4         13706916  1105904         1008   867.00          NaN           71.0
# ...            ...      ...          ...      ...          ...            ...
# 26235961  33429346  2662268         1258     7.14          NaN           70.0
# 26235962  33429334  2662268         1003    35.71          NaN           70.0
# 26235963  33429341  2662268         1089     3.86          NaN           75.0
# 26235964  33429342  2662268         1093  2071.00          NaN           70.0
# 26235965  33429338  2662268         2000     3.57          NaN           70.0
#
# ...

# %%
branded_nutrient_df
# Out:
#        id                                        name unit_name  nutrient_nbr  \
# 0    2047            Energy (Atwater General Factors)      KCAL         957.0
# 1    2048           Energy (Atwater Specific Factors)      KCAL         958.0
# 2    1001                                      Solids         G         201.0
# 3    1002                                    Nitrogen         G         202.0
# 4    1003                                     Protein         G         203.0
# ..    ...                                         ...       ...           ...
# 472  2064                            Oligosaccharides        MG           NaN
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)         G         293.4
# 474  2068                                   Vitamin E        MG         959.0
# 475  2067                                   Vitamin A        UG         960.0
# 476  2069                                 Glutathione        MG         961.0
#
#        rank
# 0     280.0
# ...
