# %%
import pandas as pd
from generatePDF import df2pdf

# %%
branded_folder = "FoodData_Central_branded_food_csv_2023-10-26"

branded_food_df = pd.read_csv(f'data_source/{branded_folder}/food.csv')
branded_food_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/food_nutrient.csv')
branded_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/nutrient.csv')
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_27708\2773455471.py:3: DtypeWarning: Columns (2,3,4,6,9,12,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_df = pd.read_csv(f'data_source/{branded_folder}/branded_food.csv')
# C:\Users\Michael\AppData\Local\Temp\ipykernel_27708\2773455471.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_food_df = pd.read_csv(f'data_source/{branded_folder}/food.csv')
# C:\Users\Michael\AppData\Local\Temp\ipykernel_27708\2773455471.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_food_nutrient_df = pd.read_csv(f'data_source/{branded_folder}/food_nutrient.csv')

# %%
branded_df = pd.read_csv(f'data_source/{branded_folder}/branded_food.csv')
# Out:
# C:\Users\Michael\AppData\Local\Temp\ipykernel_27708\443682021.py:1: DtypeWarning: Columns (2,3,4,6,9,12,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   branded_df = pd.read_csv(f'data_source/{branded_folder}/branded_food.csv')

# %%
branded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1947155 entries, 0 to 1947154
# Data columns (total 20 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   fdc_id                       int64
#  1   brand_owner                  object
#  2   brand_name                   object
#  3   subbrand_name                object
#  4   gtin_upc                     object
#  5   ingredients                  object
#  6   not_a_significant_source_of  object
#  7   serving_size                 float64
#  8   serving_size_unit            object
#  9   household_serving_fulltext   object
#  10  branded_food_category        object
#  11  data_source                  object
#  12  package_weight               object
#  13  modified_date                object
#  14  available_date               object
#  15  market_country               object
#  16  discontinued_date            float64
#  17  preparation_state_code       object
#  18  trade_channel                object
#  19  short_description            object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 297.1+ MB

# %%
branded_df
# Out:
#           fdc_id                               brand_owner     brand_name  \
# 0        1105904  Richardson Oilseed Products (US) Limited            NaN
# 1        1105905                     CAMPBELL SOUP COMPANY            NaN
# 2        1105906                     CAMPBELL SOUP COMPANY            NaN
# 3        1105907                     CAMPBELL SOUP COMPANY            NaN
# 4        1105908                     CAMPBELL SOUP COMPANY            NaN
# ...          ...                                       ...            ...
# 1947150  2662264                             Target Stores  MARKET PANTRY
# 1947151  2662265                             Target Stores  MARKET PANTRY
# 1947152  2662266                             Target Stores  MARKET PANTRY
# 1947153  2662267                             Target Stores  MARKET PANTRY
# 1947154  2662268                       General Mills, Inc.           EPIC
#
#         subbrand_name      gtin_upc  \
# 0                 NaN   27000612323
# 1                 NaN   51000198808
# 2                 NaN   51000213273
# 3                 NaN   51000213303
# 4                 NaN   51000224637
# ...               ...           ...
# 1947150           NaN   85239112977
# 1947151           NaN   85239113011
# 1947152           NaN   85239113059
# 1947153           NaN   85239113493
# 1947154           NaN  732153028593
#
#                                                ingredients  \
# 0                                            Vegetable Oil
# 1        INGREDIENTS: BEEF STOCK, CONTAINS LESS THAN 2%...
# 2        INGREDIENTS: CLAM STOCK, POTATOES, CLAMS, CREA...
# 3        INGREDIENTS: WATER, CREAM, BROCCOLI, CELERY, V...
# 4        INGREDIENTS: CHICKEN STOCK, CONTAINS LESS THAN...
# ...                                                    ...
# 1947150  REDUCED FAT CHEDDAR CHEESE (PASTEURIZED PART-S...
# 1947151   PASTEURIZED MILK, SALT, CHEESE CULTURE, ENZYMES.
# 1947152  PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYM...
# 1947153  POPCORN, PALM OIL, SALT, NATURAL AND ARTIFICIA...
# 1947154  BEEF, BEEF LIVER, SEA SALT, BLACK PEPPER, ONIO...
#
#         not_a_significant_source_of  serving_size serving_size_unit  \
# 0                               NaN          15.0                ml
# 1                               NaN         240.0                ml
# 2                               NaN         440.0                 g
# 3                               NaN         440.0                 g
# 4                               NaN         240.0                ml
# ...                             ...           ...               ...
# 1947150                         NaN          28.0               GRM
# 1947151                         NaN          20.0               GRM
# 1947152                         NaN          24.0               GRM
# 1947153                         NaN          30.0               GRM
# 1947154                         NaN          28.0               GRM
#
#         household_serving_fulltext                     branded_food_category  \
# 0                              NaN                               Oils Edible
# 1                              NaN                     Herbs/Spices/Extracts
# 2                              NaN                            Prepared Soups
# 3                              NaN                            Prepared Soups
# 4                              NaN                     Herbs/Spices/Extracts
# ...                            ...                                       ...
# 1947150                   0.25 cup                                    Cheese
# 1947151                    1 SLICE                                    Cheese
# 1947152                    1 PIECE                                    Cheese
# 1947153                        NaN  Popcorn, Peanuts, Seeds & Related Snacks
# 1947154                   6 pieces                              Other Snacks
#
#         data_source   package_weight modified_date available_date  \
# 0              GDSN              NaN    2020-10-02     2020-11-13
# 1              GDSN              NaN    2020-09-12     2020-11-13
# 2              GDSN              NaN    2020-09-01     2020-11-13
# 3              GDSN              NaN    2020-09-01     2020-11-13
# 4              GDSN              NaN    2020-10-03     2020-11-13
# ...             ...              ...           ...            ...
# 1947150          LI       8 oz/226 g    2023-09-01     2023-10-26
# 1947151          LI       7 oz/198 g    2023-09-08     2023-10-26
# 1947152          LI      20 oz/567 g    2023-08-31     2023-10-26
# 1947153          LI  64.8 oz/1.84 kg    2023-09-01     2023-10-26
# 1947154          LI      2.5 oz/71 g    2023-09-22     2023-10-26
#
#         market_country  discontinued_date preparation_state_code  \
# 0        United States                NaN                    NaN
# 1        United States                NaN                    NaN
# 2        United States                NaN                    NaN
# 3        United States                NaN                    NaN
# 4        United States                NaN                    NaN
# ...                ...                ...                    ...
# 1947150  United States                NaN                    NaN
# 1947151  United States                NaN                    NaN
# 1947152  United States                NaN                    NaN
# 1947153  United States                NaN                    NaN
# 1947154  United States                NaN                    NaN
#
#         trade_channel short_description
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 1947150           NaN               NaN
# 1947151           NaN               NaN
# 1947152           NaN               NaN
# 1947153           NaN               NaN
# 1947154           NaN               NaN
#
# [1947155 rows x 20 columns]

# %%
branded_food_df
# Out:
#           fdc_id     data_type  \
# 0        1105904  branded_food
# 1        1105905  branded_food
# 2        1105906  branded_food
# 3        1105907  branded_food
# 4        1105908  branded_food
# ...          ...           ...
# 1947150  2662264  branded_food
# 1947151  2662265  branded_food
# 1947152  2662266  branded_food
# 1947153  2662267  branded_food
# 1947154  2662268  branded_food
#
#                                                description  food_category_id  \
# 0                               WESSON Vegetable Oil 1 GAL               NaN
# 1                                       SWANSON BROTH BEEF               NaN
# 2                 CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER               NaN
# 3              CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI               NaN
# 4                                    SWANSON BROTH CHICKEN               NaN
# ...                                                    ...               ...
# 1947150  SHARP CHEDDAR REDUCED FAT SHREDDED CHEESE, SHA...               NaN
# 1947151                HAVARTI DELI SLICED CHEESE, HAVARTI               NaN
# 1947152  COLBY JACK A BLEND OF COLBY & MONTEREY JACK CH...               NaN
# 1947153       EXTRA BUTTER MICROWAVE POPCORN, EXTRA BUTTER               NaN
# 1947154  BEEF & BEEF LIVER BITES WITH SEA SALT, BEEF & ...               NaN
#
#         publication_date market_country trade_channel  \
# 0             2020-11-13  United States           NaN
# 1             2020-11-13  United States           NaN
# 2             2020-11-13  United States           NaN
# 3             2020-11-13  United States           NaN
# 4             2020-11-13  United States           NaN
# ...                  ...            ...           ...
# 1947150       2023-10-26  United States           NaN
# 1947151       2023-10-26  United States           NaN
# 1947152       2023-10-26  United States           NaN
# 1947153       2023-10-26  United States           NaN
# 1947154       2023-10-26  United States           NaN
#
#                                               microbe_data
# 0        [{"min_value":null,"uom":null,"microbe_method"...
# 1        [{"min_value":null,"uom":null,"microbe_method"...
# 2        [{"min_value":null,"uom":null,"microbe_method"...
# 3        [{"min_value":null,"uom":null,"microbe_method"...
# 4        [{"min_value":null,"uom":null,"microbe_method"...
# ...                                                    ...
# 1947150  [{"min_value":null,"uom":null,"microbe_method"...
# 1947151  [{"min_value":null,"uom":null,"microbe_method"...
# 1947152  [{"min_value":null,"uom":null,"microbe_method"...
# 1947153  [{"min_value":null,"uom":null,"microbe_method"...
# 1947154  [{"min_value":null,"uom":null,"microbe_method"...
#
# [1947155 rows x 8 columns]
